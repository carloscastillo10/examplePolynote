# %% [markdown]
# # SCALA<br>

# %%
val scalaDF = spark.createDataFrame(List((8, "bat"),
(64, "mouse"),
(-27, "horse")))

# %%
scalaDF

# %% [markdown]
# ![dataFrame.png](attachment:dataFrame.png)

# %% [markdown]
# ![dataFrameGraphic.png](attachment:dataFrameGraphic.png)
